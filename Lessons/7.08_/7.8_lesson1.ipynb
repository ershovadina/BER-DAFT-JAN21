# %%
import pandas as pd
from sklearn.datasets import load_boston
X, y = load_boston(return_X_y=True)
print(X.shape)
print(y.shape)

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
model = DecisionTreeRegressor()
cross_val_score(model, X_train, y_train, cv=10)
# Out:
# (506, 13)
# (506,)
# array([0.81966208, 0.70595037, 0.88839323, 0.76595444, 0.28696039,
#        0.83237115, 0.79447812, 0.60013164, 0.88600119, 0.57779034])

# %%
model1 = DecisionTreeRegressor()
distinct data sets by repeatedly sampling observations from the original data set
from sklearn.linear_model import LinearRegression
model2 = LinearRegression()

from sklearn.neighbors import KNeighborsRegressor
model3 = KNeighborsRegressor()

# %%
import numpy as np
model_pipeline = [model1, model2, model3]
model_names = ['Regression Tree', 'Linear Regression', 'KNN']
scores = {}
i=0
for model in model_pipeline:
    mean_score = np.mean(cross_val_score(model, X_train, y_train, cv=10))
    scores[model_names[i]] = mean_score
    i = i+1
print(scores)
# Out:
# {'Regression Tree': 0.7206958520939624, 'Linear Regression': 0.7019903990821521, 'KNN': 0.5051790633941532}

# %% [markdown]
# ## Lesson 2
